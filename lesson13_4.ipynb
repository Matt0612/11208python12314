# %%
import numpy as np
import pandas as pd
#該程式會使用到Numpy & Pandas
n1 = np.random.randint(50,100,size=(10,))
s1 = pd.Series(data=n1,index=[f"學生{i+1}"for i in range(10)])
display(s1+50)
display(s1.values)#產生的10筆亂數
display(s1.index)
# Out:
# 學生1     115
# 學生2     107
# 學生3     108
# 學生4     125
# 學生5     103
# 學生6     138
# 學生7     116
# 學生8     130
# 學生9     131
# 學生10    123
# dtype: int64
# array([65, 57, 58, 75, 53, 88, 66, 80, 81, 73])
# Index(['學生1', '學生2', '學生3', '學生4', '學生5', '學生6', '學生7', '學生8', '學生9', '學生10'], dtype='object')

# %%
#去網路上查名字帶入於python中
import requests
import pandas as pd

# 設定time為獲取中文姓名100筆的倍數。time=3，就是300筆的意思。
times = 1
cnames = []
for x in range(times):
    url = 'http://www.richyli.com/name/index.asp'
    r = requests.get(url)
    r.encoding = 'big5'
    
    # 將網頁中的資料以分行的方式存成文字檔
    result = r.text.splitlines()
    
    # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
    char_index = result[114].rfind("、")
    temp = result[114][:char_index]
    
    # 將temp的100筆姓名新增到cnames中
    cnames.append(temp)

# 將每100筆姓名的list加一個「、」，再組合成字串存到my_names中
my_names = "、".join(str(x) for x in cnames)
print(my_names)
# Out:
# 陳建德、張佩樺、林泰成、趙承為、張嘉新、王俊男、陳振芷、賴虹歡、黃易愛、林慧霖、林威宇、陳宗伶、潘亮鴻、程麗珠、顏雅芬、賴素貞、趙夙希、簡志珊、劉琇強、林惟霖、黃雅書、方玉婷、溫政瑤、王雯婷、黃佩蓉、周政翰、黃妍軒、李明蓁、謝明季、陳嘉山、何方函、梁協良、楊亦穎、戴嘉琪、賴建銘、黃雅幸、林定胤、林江淳、洪國彬、何可岳、黃美冰、邱俊杰、張克誠、周孝江、蔡宜菱、陳怡雯、黃欣穎、劉容瑄、李秀玲、陳依蓁、陳威良、林佳蓉、邊怡樺、阮筱佐、魯孝倩、倪靜宜、危佩君、許心勇、蔡慧敏、賴淑惠、周怡雪、張仰裕、林冠其、李惠茹、陳豐萱、黃麗美、林俊佑、蔡原芃、林秀琪、蘇佳蓉、潘惠雯、林介柔、屈怡均、林瑞達、謝雅竹、黃士生、陳羿苓、王正偉、林佩蘋、何凱元、楊佩如、蔡宛發、陳博樺、陳永文、楊智岳、朱卉琴、江哲豪、陳美慧、許建豪、張俊霖、張家霖、吳淑航、謝雅文、謝淑娟、陳惠美、楊初峰、陳君江、張書花、李威廷、林凱鈞

# %%
#這code是取上面的100pcs的名字資料
import requests
def getNames(num):
    times = 1
    cnames = []
    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        # 將網頁中的資料以分行的方式存成文字檔
        result = r.text.splitlines()
        
        # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)
    print(type(cnames[0]))
    names = cnames[0].split('、')
    return names[:num]


names = getNames(100) #names等於變數
# Out:
# <class 'str'>

# %%
import numpy as np
import pandas as pd

n2 = np.random.randint(50,100,size=(50,5))
dataFrame = pd.DataFrame(data=n2,
             index=names[:50],#前50筆名字資料
             columns=["國文","英文","數學","地理","歷史"]
             )
dataFrame

#如果要多一欄的話,變成索引使用1~50,增加姓名欄位
# 錢茜�琚B羅宇政  95  62  57  99  84  397
# 蔡崇泰       73  79  76  79  76  383
# 張俊銘       63  66  77  95  55  356
# 李秀諭       60  69  62  78  65  334
# 李宗佩       53  69  51  52  76  301
# 殷政宏       78  86  88  86  89  427
# 李世豪       76  75  55  85  89  380
# 張承穎       79  67  69  53  59  327
# 蘇信宏       97  82  92  60  73  404
# 黃文月       61  80  55  74  77  347
# 楊寧苓       99  55  54  56  74  338
# 魏昱義       76  74  91  91  76  408
# 林昱盈       79  94  76  81  93  423
# 靳佩君       55  65  53  58  67  298
# 林郁姍       99  97  60  73  99  428
# 傅威任       52  92  57  93  96  390
# 李凱元       56  70  82  81  96  385
# 司慧茹       85  61  59  56  58  319
# 陳志琪       60  62  57  67  76  322
# 陳永軒       60  58  51  84  74  327
# 程怡如       95  65  89  96  81  426
# 黃琳佐       72  82  87  50  87  378

# %%
#以下是接下來把所生產的資料下載下來(TXT or CSV)
import requests
def getNames():
    times = 3
    cnames = []
    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        # 將網頁中的資料以分行的方式存成文字檔
        result = r.text.splitlines()
        
        # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)    
    return cnames


names = getNames()

# %%
#使用"、"符號,連結3個陣列元素
names_str = "、".join(names)
names_list = names_str.split("、") #有299筆的list
newLine_name = "\n".join(names_list)  #有換行符號的字串
print(newLine_name)
# Out:
# 林香桓
# 陳佳蓉
# 鐘育萱
# 郭世雪
# 林淑慧
# 林萬平
# 宋晏泰
# 謝依泰
# 黎成任
# 林茹正
# 劉子韋
# 李珍綸
# 林炳鈺
# 藍怡婷
# 林庭瑋
# 李育冰
# 郭怡菁
# 馮金真
# 王夙妃
# 黎昌函
# 劉智強
# 李育意
# 王建成
# 鍾淑梅
# 葉俊玫
# 黃幸蕙
# 趙致岑
# 陳麗富
# 呂建宇
# 陳君玲
# 陳怡靜
# 陳世郁
# 夏雅惠
# 郭于倫
# 陳家榮
# 楊羽維
# 邱淑青
# 陳學駿
# 崔莉雯
# 張之娟
# 陳群芝
# 支雅惠
# 鄭政勳
# 黃彥凌
# 李雅雯
# 胡信宏
# 賴妙慈
# 李健山
# 郭永季
# 金翠毓
# 黃愛美
# 蔡政喜
# 黃威辛
# 陳嘉妏
# 陳逸佩
# 黃國芸
# 謝婉婷
# 李志宏
# 陳怡君
# 張秀宸
# 沈名辰
# 劉皇哲
# 柯俊穎
# 蘇俊宇
# 李宗喬
# 林威廷
# 蔡宗憲
# 黃玉芳
# 賴心怡
# 池青喬
# 林平豪
# 陳彥汝
# 宋佳穎
# 陸怡文
# 鄭兆凡
# 許琬婷
# 黃珮芬
# 郭亭君
# 廉江紋
# 陳冠茜
# 陳逸昆
# 謝岳合
# 林亮妏
# 王麗霞
# 張韋喬
# 陳行妮
# 謝艾禎
# 陳宜凱
# 夏明軒
# 房鈺娟
# 毛康東
# 王志州
# 許宏儒
# 饒愛�琚B許行君
# 白行哲
# 王真揚
# 胡俞霖
# 宋雅婷
# 王則瑋
# 周蘭勳
# 楊佳峰
# 彭儒妍
# 林承翰
# 魏昀萍
# 許雅郁
# 潘富榮
# 胡桂林
# 林家綺
# 王志卿
# 陳淑娟
# 徐佩樺
# 陳子全
# 吳冰杰
# 陳智仁
# 陳怡杰
# 吳建湖
# 白牧杰
# 黃嬌婷
# 黃建秋
# 朱雅婷
# 彭惠婷
# 林妙琪
# 郭淑慧
# 李火揚
# 吳建宏
# 王智超
# 蘇婉玲
# 張惠其
# 袁晏誠
# 白詠淑
# 曹家賢
# 陳婷念
# 劉法琇
# 趙苡軒
# 白裕幸
# 潘禹珊
# 林寧法
# 洪季劭
# 黃偉智
# 錢哲銘
# 林韻綠
# 楊建宏
# 王文揚
# 張昀睿
# 李靜怡
# 胡宇軒
# 林曉萍
# 林冠成
# 邱雅惠
# 李正平
# 蔡依湖
# 葉靜怡
# 陳依潔
# 楊家仲
# 陳逸春
# 白順芸
# 黃佳泰
# 毛威妮
# 邱彥儒
# 張佩璇
# 師雅茹
# 劉文旭
# 鄭雅欣
# 吳穎行
# 賴怡靖
# 賴俊昆
# 吳嘉忠
# 周萱璇
# 趙鈺婷
# 羅怡萍
# 陳盈芝
# 陳冠鑫
# 黃喜為
# 農靜芳
# 陳國俊
# 王怡其
# 陳財岳
# 陳于庭
# 簡維辰
# 王鈺婷
# 潘家瑋
# 鄭國瑋
# 方馥皓
# 周奕穎
# 林士湖
# 黎彥君
# 楊佩珊
# 蔣薇名
# 黃軒豪
# 彭淑芬
# 林盈霞
# 林韋佩
# 陳建姍
# 符慧玲
# 郭怡如
# 席俐辰
# 毛明軒
# 耿宜珊
# 張佩珊
# 郭俊福
# 劉均盈
# 曾松夫
# 林苡勳
# 易振瑋
# 馮香郁
# 劉佳燕
# 陳怡珊
# 胡儒恭
# 李宜芳
# 林宗翰
# 邱羽慈
# 賴淑君
# 陳淑如
# 陳俊傑
# 楊俊宇
# 林偉倫
# 王秀英
# 林惠美
# 潘怡如
# 翁佳蓉
# 王秀軒
# 黎雅婷
# 王林珍
# 楊士傑
# 陳家豪
# 黃文傑
# 陳重彬
# 黃穎江
# 葉麗娟
# 吳智堯
# 馬泰哲
# 李佩佳
# 喬宜婷
# 張祐妹
# 林延裕
# 馮佳玲
# 馬維倫
# 陳昱恭
# 張惠谷
# 陳瓊昇
# 吳裕翔
# 王彥儒
# 林俊霖
# 張智妃
# 杜家瑋
# 許惠茵
# 黃佩君
# 陳孝睿
# 鄭修恩
# 劉婉菁
# 方雅筑
# 李淑芬
# 陳均旺
# 許秀玲
# 黃惠雯
# 黃信佩
# 徐水妤
# 林玉婷
# 王穎成
# 張曉一
# 吳嬌紹
# 許家弘
# 黃穎尹
# 姚怡璇
# 陳至君
# 吳宜蘋
# 林哲孜
# 林建志
# 杜阿達
# 時仲樂
# 鄭則和
# 游泰義
# 陳彥舜
# 錢淑君
# 蔡宜君
# 陳政宏
# 林昇宜
# 黃淑惠
# 吳佳陽
# 吳亦岑
# 鄭雅季
# 王怡慧
# 吳孟坤
# 王台昌
# 鄧家瑜
# 鄭惟妍
# 劉睿青
# 李怡君
# 陳柏琳
# 陳怡秀
# 劉萬佩
# 淩雅娟
# 王佳雯
# 黃碧雪
# 蕭婕妤
# 賴容睿
# 陳依婷
# 楊文偉
# 王奕辰

# %%
with open("lesson13_names.csv",mode="w",encoding='utf-8',newline="") as file:
    file.write(newLine_name)
