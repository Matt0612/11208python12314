# %%
import ffn
prices = ffn.get('1233.TW', start='2010-01-01')
prices
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                1233tw
# Date
# 2010-01-04  21.078730
# 2010-01-05  21.431015
# 2010-01-06  21.577806
# 2010-01-07  21.724594
# 2010-01-08  21.372305
# ...               ...
# 2023-08-14  35.000000
# 2023-08-15  35.650002
# 2023-08-16  35.750000
# 2023-08-17  36.250000
# 2023-08-18  36.200001
#
# [3337 rows x 1 columns]

# %%
ax = prices.rebase().plot(figsize=(10, 5))

# %%
import csv
import pandas as pd
def getStockNames() -> pd.Series:
    with open('codeSearch.csv',encoding='utf-8',newline='') as file:
        next(file)
        csv_reader = csv.reader(file)
        stock_codes = {}
        for item in csv_reader:
            key  =  item[2]
            stock_codes[key] = item[3]
        
    code_series:pd.Series = pd.Series(stock_codes)
    return code_series

getStockNames()
# Out:
# 1101      台泥
# 1102      亞泥
# 1103      嘉泥
# 1104      環泥
# 1108      幸福
#         ...
# 9944      新麗
# 9945     潤泰新
# 9946    三發地產
# 9955      佳龍
# 9958     世紀鋼
# Length: 975, dtype: object
